# %%
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define paths to your files in Google Drive
data_file_path = '/content/drive/MyDrive/data_obat/dataset/drug/update_drug_1219_14.xlsx'
condition_mapping_path = '/content/drive/MyDrive/data_obat/dataset/disease/condition_3.xlsx'
output_file_path = '/content/drive/MyDrive/data_obat/dataset/drug/update_drug_1219_15.xlsx'

# Load your Excel files
df = pd.read_excel(data_file_path)
condition_df = pd.read_excel(condition_mapping_path)

# Create the condition mapping dictionary from the DataFrame
condition_mapping = condition_df.set_index('Disease Name')['Mapped Disease Names from Symptoms'].to_dict()

# Convert each keyword string to a list of keywords for easier processing
for condition, keywords in condition_mapping.items():
    condition_mapping[condition] = [keyword.strip().lower() for keyword in keywords.split(',')]

# Initialize a counter for the number of updated rows
updated_rows_count = 0

# Define a function to check conditions and update disease
def add_disease(row):
    global updated_rows_count
    # Get the current disease value and handle NaN values
    disease_value = str(row['disease']).lower() if pd.notnull(row['disease']) else ""

    # Split the disease value into individual words or phrases for exact matching
    disease_words = set(disease_value.split(', '))

    # Iterate through each condition and its associated keywords
    for condition, keywords in condition_mapping.items():
        # Check if any of the keywords match exactly with the words in disease
        if any(keyword in disease_words for keyword in keywords):
            # Add the condition if it is not already present in the 'disease' column
            if condition not in disease_value:
                # Combine the condition with the current disease value, handling NaN or empty cases
                new_disease = f"{disease_value}, {condition}".strip(", ")
                # Increment the counter for updated rows
                updated_rows_count += 1
                # Print debug information
                print(f"Row {row.name}: Added '{condition}' to disease. Updated disease: '{new_disease}'")
                return new_disease
    return row['disease']

# Apply the function to each row and keep the index for better debugging
df = df.reset_index()  # Reset index to maintain row numbers
df['disease'] = df.apply(add_disease, axis=1)

# Save the modified DataFrame back to an Excel file in Google Drive
df.to_excel(output_file_path, index=False)

# Print the total number of updated rows
print(f"Total number of rows updated: {updated_rows_count}")
print(f"Output saved to {output_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Row 2: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 12: Added 'urinary tract infection' to disease. Updated disease: 'muscle pain (myalgia), sprain, bruises, fever, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute upper, immunization, varicella, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, acute kidney failure, immunization, rhinosinusitis, rhinosinusitis acute, bacterial, urinary tract infection'
# Row 13: Added 'urinary tract infection' to disease. Updated disease: 'muscle pain (myalgia), sprain, bruises, fever, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute upper, immunization, varicella, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, acute kidney failure, immunization, rhinosinusitis, rhinosinusitis acute, bacterial, urinary tract infection'
# Row 14: Added 'urinary tract infection' to disease. Updated disease: 'gout, muscle pain (myalgia), joint pain, fever, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, hemarthrosis, hepatitis a, acute upper, immunization, varicella, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, hemarthrosis, hepatitis a, acute kidney failure, immunization, rhinosinusitis, rhinosinusitis acute, bacterial, urinary tract infection'
# Row 24: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 33: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 74: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 81: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 88: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 106: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'skin infection, bacterial infection, necrosis of pulp, acute upper, varicella, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 110: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hyperlipidemia, Hyperlipidemia'
# Row 214: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 244: Added 'urinary tract infection' to disease. Updated disease: 'allergy, allergy, inflammatory, inflammatory, immunosuppression, necrosis of pulp, atopic dermatitis, gingivitis, varicella, urinary tract infection'
# Row 247: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 248: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 252: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 266: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 292: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 293: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 295: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 298: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 299: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 301: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 302: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroparesis, gerd, nausea & vomiting, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 313: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 321: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, electrolyte deficiency, hypertonic dehydration, hypokalemia, carbohydrate imbalance, electrolyte imbalance, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 348: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hyperlipidemia, Hyperlipidemia'
# Row 351: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, pneumonia, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 353: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 387: Added 'urinary tract infection' to disease. Updated disease: 'allergy, inflammatory, immunosuppression, atopic dermatitis, necrosis of pulp, gingivitis, varicella, urinary tract infection'
# Row 394: Added 'urinary tract infection' to disease. Updated disease: 'anxiety, muscle spasm, inflammatory, cerebral palsy, paraplegia, tetanus, heart attack, necrosis of pulp, mild heart attack, kidney disease, gingivitis, ear infection, external otitis, otitis media, urinary tract infection'
# Row 436: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 449: Added 'urinary tract infection' to disease. Updated disease: 'allergy, inflammatory, rheumatic diseases, atopic dermatitis, necrosis of pulp, gingivitis, varicella, urinary tract infection'
# Row 543: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, functional dyspepsia, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 545: Added 'urinary tract infection' to disease. Updated disease: 'mild pain, moderate pain, dysmenorrhea, headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, endometriosis, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 549: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 550: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 551: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 552: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 555: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 556: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 557: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 576: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'schizophrenia, psychosis, paranoia, mania, nausea, vomiting, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 582: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'acidosis, dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 586: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'acidosis, dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 588: Added 'Diarrhea' to disease. Updated disease: 'iodine deficiency, iodine deficiency, acute diarrhea, diarrhea, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 593: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 604: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, postoperative nausea and vomiting, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 605: Added 'urinary tract infection' to disease. Updated disease: 'fever, toothache, headache, postoperative pain, menstrual pain, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, pneumonia, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 613: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 631: Added 'urinary tract infection' to disease. Updated disease: 'allergy, inflammatory, immunosuppressive, atopic dermatitis, necrosis of pulp, gingivitis, varicella, urinary tract infection'
# Row 643: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'hypertension, microalbuminuria, diabetic nephropathy, diabetes mellitus, diabetes, type 2 diabetes, heart disease, chronic kidney failure, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 655: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'delayed emesis, nausea, vomiting, postoperative nausea and vomiting, radiation therapy-related nausea and vomiting, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 712: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, functional dyspepsia, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 734: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 744: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'mild pain, moderate pain, headache, toothache, primary dysmenorrhea, muscle pain (myalgia), postoperative pain, acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, dengue fever, avian flu, cavity, hepatitis b, mild heart attack, acute upper, pulpitis, impacted teeth, singapore flu, hypermagnesemia, dental abscess, brucellosis, pulmonary fibrosis, hepatitis b, hemorrhagic stroke, acute upper, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 798: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 853: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 885: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, type 1 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 919: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 941: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, chemotherapy-induced nausea and vomiting (cinv), radiation-induced nausea, migraine, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 957: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 973: Added 'Diarrhea' to disease. Updated disease: 'acute diarrhea, chronic diarrhea, Diarrhea'
# Row 1002: Added 'urinary tract infection' to disease. Updated disease: 'fever, hyperthermia, acute upper, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute upper, immunization, varicella, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, acute kidney failure, immunization, rhinosinusitis, rhinosinusitis acute, bacterial, urinary tract infection'
# Row 1007: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1155: Added 'Chronic Obstructive Pulmonary Disease' to disease. Updated disease: 'acute respiratory distress syndrome, chronic obstructive pulmonary disease, overdose, acute respiratory distress syndrome, acute respiratory distress syndrome, Chronic Obstructive Pulmonary Disease'
# Row 1167: Added 'Anxiety, generalized anxiety disorder' to disease. Updated disease: 'anxiety disorders, depression, panic disorder, agoraphobia, Anxiety, generalized anxiety disorder'
# Row 1168: Added 'Anxiety, generalized anxiety disorder' to disease. Updated disease: 'anxiety disorders, depression, panic disorder, agoraphobia, Anxiety, generalized anxiety disorder'
# Row 1170: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'gastritis, gerd, nausea, gastritis, gastroenteritis, pharyngitis, dysentery, gerd, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, nutrition in pregnancy, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, kidney stones, common cold (cc), dysentry, hemorrhagic fever, dengue fever'
# Row 1193: Added 'Anxiety, generalized anxiety disorder' to disease. Updated disease: 'anxiety disorders, depression, panic disorder, agoraphobia, Anxiety, generalized anxiety disorder'
# Row 1212: Added 'urinary tract infection' to disease. Updated disease: 'muscle pain (myalgia), ear infection, nasal infection, tonsillopharyngitis acute, fever, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute upper, immunization, varicella, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, acute kidney failure, immunization, rhinosinusitis, rhinosinusitis acute, bacterial, urinary tract infection'
# Row 1213: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'arthritis, rheumatoid arthritis, osteoarthritis, toothache, migraine, gout, pulpitis, dental abscess, cavity, gingivitis, impacted teeth, sensitive teeth, dental abscess, tooth decay, necrosis of pulp, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 1216: Added 'urinary tract infection' to disease. Updated disease: 'inflammatory, pruritus, dermatitis, psoriasis, atopic dermatitis, necrosis of pulp, gingivitis, ear infection, external otitis, otitis media, urinary tract infection'
# Row 1218: Added 'Anxiety, generalized anxiety disorder' to disease. Updated disease: 'sleep disorders, anxiety disorders, psychosis, trauma, Anxiety, generalized anxiety disorder'
# Row 1219: Added 'Anxiety, generalized anxiety disorder' to disease. Updated disease: 'sleep disorders, anxiety disorders, psychosis, trauma, Anxiety, generalized anxiety disorder'
# Row 1225: Added 'Anxiety, generalized anxiety disorder' to disease. Updated disease: 'anxiety disorders, depression, panic disorder, agoraphobia, Anxiety, generalized anxiety disorder'
# Row 1230: Added 'Chronic Obstructive Pulmonary Disease' to disease. Updated disease: 'chronic obstructive pulmonary disease, chronic bronchitis, asthma, chronic bronchitis, asthma, chronic bronchitis, asthma, bronchitis, bronchitis uncomplicated acute, Chronic Obstructive Pulmonary Disease'
# Row 1253: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'swollen gums, toothache, dysmenorrhea, headache, acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, dengue fever, avian flu, cavity, hepatitis b, mild heart attack, acute upper, pulpitis, impacted teeth, endometriosis, hypermagnesemia, dental abscess, glandular fever, hepatitis b, hemorrhagic stroke, acute upper, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 1254: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'gastritis, peptic ulcer, duodenal ulcer, nausea, gastroenteritis, pharyngitis, dysentery, gerd, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, nutrition in pregnancy, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, kidney stones, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1286: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1290: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, influenza, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1295: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1298: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1304: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroenteritis, dysentery, disseminated intravascular coagulation, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, hemorrhagic stroke, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1305: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroenteritis, dysentery, disseminated intravascular coagulation, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, hemorrhagic stroke, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1318: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1325: Added 'urinary tract infection' to disease. Updated disease: 'inflammatory, nyeri, fever, acute upper, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute kidney failure, immunization, varicella, urinary tract infection'
# Row 1335: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, gastroenteritis, dysentery, gerd, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, kidney stones, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1339: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, diarrhea, chronic diarrhea, chronic diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1354: Added 'Diarrhea' to disease. Updated disease: 'empyema, lung abscess, septicemia, peritonitis, intra-abdominal abscess, uterine infection, cellulitis, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1369: Added 'Diarrhea' to disease. Updated disease: 'empyema, lung abscess, septicemia, peritonitis, intra-abdominal abscess, uterine infection, cellulitis, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1377: Added 'urinary tract infection' to disease. Updated disease: 'inflammatory, necrosis of pulp, gingivitis, ear infection, external otitis, otitis media, urinary tract infection'
# Row 1402: Added 'urinary tract infection' to disease. Updated disease: 'infeksi saluran pernafasan, allergy, inflammatory, necrosis of pulp, atopic dermatitis, gingivitis, varicella, urinary tract infection'
# Row 1403: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'nyeri, dysmenorrhea, toothache, gingivitis, pulpitis, impacted teeth, endometriosis, dental abscess, cavity, necrosis of pulp, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 1404: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'nyeri, dysmenorrhea, toothache, gingivitis, pulpitis, impacted teeth, endometriosis, dental abscess, cavity, necrosis of pulp, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 1421: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, functional dyspepsia, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1422: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, functional dyspepsia, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1439: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1455: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 1457: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, type 2 diabetes, heart disease, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 1470: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1477: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1480: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1499: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'hemorrhage, placenta previa, hemorrhagic fever, dengue fever'
# Row 1507: Added 'urinary tract infection' to disease. Updated disease: 'dismenore primer, headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1518: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1519: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1522: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'osteoartritis, toothache, headache, acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, dengue fever, avian flu, cavity, hepatitis b, mild heart attack, hemorrhagic stroke, acute upper, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 1524: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1526: Added 'urinary tract infection' to disease. Updated disease: 'fever, acute upper, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute kidney failure, immunization, varicella, urinary tract infection'
# Row 1527: Added 'urinary tract infection' to disease. Updated disease: 'fever, acute upper, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute kidney failure, immunization, varicella, urinary tract infection'
# Row 1528: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1550: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1551: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, nasal congestion, common cold (cc), sneezing, common cold (cc), cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, acute bronchitis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1563: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hypercholesterolemia, hypercholesterolemia, hyperlipidemia, Hyperlipidemia'
# Row 1564: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hypercholesterolemia, hypercholesterolemia, hyperlipidemia, Hyperlipidemia'
# Row 1565: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hypercholesterolemia, hypercholesterolemia, hyperlipidemia, Hyperlipidemia'
# Row 1566: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, joint pain, sprain, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, hemarthrosis, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, hemarthrosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1568: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hypercholesterolemia, hypercholesterolemia, hyperlipidemia, Hyperlipidemia'
# Row 1570: Added 'Cystitis' to disease. Updated disease: 'ear infection, skin infection, bladder infection, contact dermatitis, Cystitis'
# Row 1574: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1615: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'meningitis, bacterial infection, necrosis of pulp, acute upper, varicella, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 1640: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1648: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1661: Added 'urinary tract infection' to disease. Updated disease: 'nyeri, fever, acute upper, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute kidney failure, immunization, varicella, urinary tract infection'
# Row 1663: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, nasal congestion, common cold (cc), sneezing, common cold (cc), cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, acute bronchitis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1675: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1676: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1678: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1683: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1684: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1685: Added 'urinary tract infection' to disease. Updated disease: 'fever, acute upper, parotitis, dysentery, typhoid fever, lymphadenitis, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, acute kidney failure, immunization, varicella, urinary tract infection'
# Row 1686: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1688: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1693: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 1700: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, dyspepsia, gastroenteritis, dysentery, disseminated intravascular coagulation, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, hemorrhagic stroke, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 1702: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1712: Added 'urinary tract infection' to disease. Updated disease: 'headache, primary dysmenorrhea, rheumatoid arthritis, osteoarthritis, pain, inflammatory, acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, dengue fever, avian flu, hepatitis b, mild heart attack, acute upper, pharyngitis, impacted teeth, singapore flu, hypermagnesemia, tonsillopharyngitis acute, glandular fever, hepatitis b, hemorrhagic stroke, acute upper, ear infection, external otitis, otitis media, urinary tract infection'
# Row 1725: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, dengue fever, avian flu, hepatitis b, mild heart attack, acute upper, immunization, dysentery, singapore flu, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1736: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1738: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1742: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1743: Added 'urinary tract infection' to disease. Updated disease: 'headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 1754: Added 'urinary tract infection' to disease. Updated disease: 'dysmenorrhea primary, headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# ...
# Row 18611: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nyeri lambung, nausea, gastroenteritis, dysentery, gerd, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, kidney stones, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18615: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nyeri lambung, nausea, gastroenteritis, dysentery, gerd, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, kidney stones, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18616: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'asidosis, dehydration, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18617: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18619: Added 'Diarrhea' to disease. Updated disease: 'diare kronik, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 18620: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, cough, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, acute bronchitis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18625: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'kelebihan asam lambung, peptic ulcer, gastritis, nausea, nyeri lambung, gastroenteritis, dysentery, gerd, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, kidney stones, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18632: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 18633: Added 'urinary tract infection' to disease. Updated disease: 'dismenore primer, headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18634: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, pneumonia, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18645: Added 'Diarrhea' to disease. Updated disease: 'acute nonspecific diarrhea, chronic diarrhea, Diarrhea'
# Row 18646: Added 'Diarrhea' to disease. Updated disease: 'acute nonspecific diarrhea, chronic diarrhea, Diarrhea'
# Row 18653: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, pneumonia, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18655: Added 'Hyperlipidemia' to disease. Updated disease: 'loss of consciousness, head trauma, brain surgery, apoplectic hemiplegia, lower extremity paralysis, dyslipidemia, Hyperlipidemia'
# Row 18657: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, dyspepsia, mual muntah pada kemoterapi kanker, mual muntah pada radioterapi, gastroenteritis, dysentery, disseminated intravascular coagulation, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, hemorrhagic stroke, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18665: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'headache, toothache, dysmenore primer, muscle pain (myalgia), acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, brucellosis, pulmonary fibrosis, cavity, hepatitis b, mild heart attack, hemorrhagic stroke, acute upper, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 18668: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 18669: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroenteritis, dysentery, disseminated intravascular coagulation, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, hemorrhagic stroke, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18671: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hyperlipidemia, Hyperlipidemia'
# Row 18678: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'gastritis, peptic ulcer, tukak usus dua belas jari, nausea, nyeri lambung, nyeri ulu hati, kembung, gastroenteritis, dysentery, gerd, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, kidney stones, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18679: Added 'Hyperemesis Gravidarum, morning sickness, Nausea & Vomiting in Pregnancy' to disease. Updated disease: 'nausea & vomiting, nausea & vomiting, mual muntah pada kemoterapi kanker dan radioterapi, Hyperemesis Gravidarum, morning sickness, Nausea & Vomiting in Pregnancy'
# Row 18703: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'hemorrhage, placenta previa, hemorrhagic fever, dengue fever'
# Row 18708: Added 'Diarrhea' to disease. Updated disease: 'diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, Diarrhea'
# Row 18716: Added 'Hyperlipidemia' to disease. Updated disease: 'hypercholesterolemia, dyslipidemia, hiperkolesterolemia familial homozigot, hiperkolesterolemia familial heterozigot, hyperlipidemia, Hyperlipidemia'
# Row 18720: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, dypepsia, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18723: Added 'tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus' to disease. Updated disease: 'headache, toothache, dismenore primer, muscle pain (myalgia), acute upper, parotitis, impacted teeth, typhoid fever, hypermagnesemia, influenza, brucellosis, pulmonary fibrosis, cavity, hepatitis b, mild heart attack, hemorrhagic stroke, acute upper, tooth persistent, Dental caries, dental abrasion, Impacted teeth, tooth extraction, apical abscess, Periapical abscess without sinus, Periapical abscess with sinus'
# Row 18733: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18740: Added 'urinary tract infection' to disease. Updated disease: 'headache, toothache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18768: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 18779: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, gastroparesis, gastroenteritis, dysentery, disseminated intravascular coagulation, hypermagnesemia, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, hemorrhagic stroke, dyspepsia, gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18816: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, singapore flu, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18818: Added 'urinary tract infection' to disease. Updated disease: 'mild to moderate pain, dysmenorrhea, toothache, headache, fever, acute upper, parotitis, dysentery, typhoid fever, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, cavity, hepatitis a, mild heart attack, acute upper, immunization, impacted teeth, endometriosis, hypermagnesemia, influenza, brucellosis, diphtheria, pneumonia, hepatitis a, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18823: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'nausea, vomiting, dyspepsia, gastroenteritis, pharyngitis, dysentery, disseminated intravascular coagulation, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, hemorrhagic stroke, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18847: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'stomach pain, excess stomach acid, nausea, heartburn, gastroenteritis, pharyngitis, dysentery, gerd, hypermagnesemia, tonsillopharyngitis acute, dengue fever, diarrhea, pneumonia, hepatitis a, heart attack, dyspepsia, sore throat, gastritis, singapore flu, hypermagnesemia, ankylosing spondylitis, glandular fever, diphtheria, hepatitis, hepatitis a, mild heart attack, kidney stones, common cold (cc), gastritis, gastroenteritis, hemorrhagic fever, dengue fever'
# Row 18875: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 18877: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 18878: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 18879: Added 'diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes' to disease. Updated disease: 'diabetes mellitus, diabetes, gestational diabetes, diabetes insipidus, type 1 diabetes, type 2 diabetes, prediabetes'
# Row 18888: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, hemorrhagic fever, dengue fever'
# Row 18890: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dehydration, diarrhea, gastroenteritis, hypermagnesemia, ankylosing spondylitis, hypermagnesemia, ankylosing spondylitis, kidney infection, dysentry, hemorrhagic fever, dengue fever'
# Row 18910: Added 'urinary tract infection' to disease. Updated disease: 'fever, headache, dizziness, hallucination, acute upper, parotitis, dysentery, uterine atony, hypermagnesemia, tonsillopharyngitis acute, brucellosis, diarrhea, pneumonia, hepatitis a, heart disorders, acute upper, immunization, impacted teeth, uterine atony, hypermagnesemia, influenza, brucellosis, diphtheria, tuberculosis, hepatitis a, heart attack, hemorrhagic stroke, immunization, varicella, urinary tract infection'
# Row 18934: Added 'gravida, menstruation' to disease. Updated disease: 'spina bifida, cleft lip, gravida, menstruation'
# Row 18936: Added 'gravida, menstruation' to disease. Updated disease: 'spina bifida, cleft lip, gravida, menstruation'
# Row 18940: Added 'gravida, menstruation' to disease. Updated disease: 'spina bifida, cleft lip, gravida, menstruation'
# Row 18971: Added 'gravida, menstruation' to disease. Updated disease: 'spina bifida, cleft lip, gravida, menstruation'
# Row 18981: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 18982: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 18983: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 18989: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 18991: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 18992: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 19061: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 19063: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, birth defects, cleft lip, folic acid deficiency, gravida, menstruation'
# Row 19147: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, cleft lip, gravida, menstruation'
# Row 19189: Added 'gravida, menstruation' to disease. Updated disease: 'neural tube defects, spina bifida, cleft lip, birth defects, gravida, menstruation'
# Row 19378: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dengue, immunization, hemorrhagic fever, dengue fever'
# Row 19391: Added 'hemorrhagic fever, dengue fever' to disease. Updated disease: 'dengue, immunization, hemorrhagic fever, dengue fever'
# Total number of rows updated: 2440
# Output saved to /content/drive/MyDrive/data_obat/dataset/drug/update_drug_1219_15.xlsx

# %%
import pandas as pd

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define paths to your files in Google Drive
data_file_path = '/content/drive/MyDrive/data_obat/dataset/drugs_20241013_updated.xlsx'
condition_mapping_path = '/content/drive/MyDrive/data_obat/dataset/condition_mapping.xlsx'
output_file_path = '/content/drive/MyDrive/data_obat/dataset/drugs_20241013_updated2.xlsx'

# Load your Excel files
df = pd.read_excel(data_file_path)
condition_df = pd.read_excel(condition_mapping_path)

# Create the condition mapping dictionary from the DataFrame
condition_mapping = condition_df.set_index('condition')['keywords'].to_dict()

# Convert each keyword string to a list of keywords for easier processing
for condition, keywords in condition_mapping.items():
    condition_mapping[condition] = [keyword.strip().lower() for keyword in keywords.split(',')]

# Initialize a counter for the number of updated rows
updated_rows_count = 0

# Define a function to check conditions and update disease
def add_disease(row):
    global updated_rows_count

    # Check the disease value
    disease_value = row['disease']

    # Print the original disease value and its type for debugging
    print(f"Original disease value (Row {row.name}): {disease_value} (Type: {type(disease_value)})")

    # Handle NaN or non-string values
    if pd.isna(disease_value) or not isinstance(disease_value, str):
        disease_value = ""  # Treat NaN and non-string as empty string
    else:
        disease_value = disease_value.strip().lower()

    # Only split if the disease_value is a non-empty string
    disease_words = set(disease_value.split(', ')) if disease_value else set()

    # A flag to track if any updates are made
    updated = False

    # Iterate through each condition and its associated keywords
    for condition, keywords in condition_mapping.items():
        # Check if any of the keywords match exactly with the words in disease
        if any(keyword in disease_words for keyword in keywords):
            # Add the condition if it is not already present in the 'disease' column
            if condition not in disease_value:
                # Combine the condition with the current disease value, handling NaN or empty cases
                new_disease = f"{disease_value}, {condition}".strip(", ")
                updated_rows_count += 1
                updated = True
                # Print debug information
                print(f"Row {row.name}: Added '{condition}' to disease. Updated disease: '{new_disease}'")
                # Update the row's disease value
                disease_value = new_disease

    return disease_value  # Return the updated or original disease value

# Apply the function to each row and keep the index for better debugging
df = df.reset_index()  # Reset index to maintain row numbers
df['disease'] = df.apply(add_disease, axis=1)

# Save the modified DataFrame back to an Excel file in Google Drive
df.to_excel(output_file_path, index=False)

# Print the total number of updated rows
print(f"Total number of rows updated: {updated_rows_count}")
print(f"Output saved to {output_file_path}")
